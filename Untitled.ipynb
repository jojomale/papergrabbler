# %%
import urllib
import requests
import lxml.html

# %%
url = 'https://www.sciencedirect.com/science/article/pii/S0377027318301148'
#url = 'https://www.sciencedirect.com/science/article/pii/S037702731830129X'

# %%
r = requests.get(url)

# %%
r.content.splitlines()
# Out:
# [b'<!doctype html>',
#  b'  <!--[if IE 9]><html class="ie9" lang="en"><![endif]-->',
#  b"  <html lang='en'>",
#  b'    <head>',
#  b'      <meta name="citation_pii" content="S0377027318301148" />',
#  b'<meta name="citation_issn" content="0377-0273" />',
#  b'<meta name="citation_volume" content="359" />',
#  b'<meta name="citation_lastpage" content="77" />',
#  b'<meta name="citation_publisher" content="Elsevier" />',
#  b'<meta name="citation_firstpage" content="68" />',
#  b'<meta name="citation_fulltext_world_readable" content="" />',
#  b'<meta name="citation_journal_title" content="Journal of Volcanology and Geothermal Research" />',
#  b'<meta name="citation_type" content="JOUR" />',
#  b'<meta name="citation_doi" content="10.1016/j.jvolgeores.2018.06.017" />',
#  b'<meta name="dc.identifier" content="10.1016/j.jvolgeores.2018.06.017" />',
#  b'<meta name="citation_article_type" content="Full-length article" />',
# ...

# %%
url = 'https://www.sciencedirect.com/science/article/pii/S037702731830129X'
headers = {'User-Agent': 'Mozilla', 'Referer': 'https://www.sciencedirect.com/science/article/pii/S037702731830129X'}
r = requests.get(url)

# %%
r.headers
# Out:
# {'Content-Encoding': 'gzip', 'Content-Type': 'text/html; charset=utf-8', 'Server': 'nginx', 'Vary': 'accept-encoding', 'X-Content-Type-Options': 'nosniff', 'x-correlation-id': 'arp-939dd48d-8e95-4d63-99df-90b229c18b5c', 'X-ELS-Platform': 'sdfe', 'X-Region': 'us-east-1', 'X-Router': 'true', 'x-sdfe-corr-id': 'arp-939dd48d-8e95-4d63-99df-90b229c18b5c', 'X-XSS-Protection': '1; mode=block', 'Content-Length': '20718', 'Expires': 'Wed, 26 Sep 2018 21:46:38 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Wed, 26 Sep 2018 21:46:38 GMT', 'Connection': 'keep-alive', 'Set-Cookie': 'EUID=a5a968e2-6700-485f-99cf-19a59afc60d4;Version=1;Domain=.sciencedirect.com;Path=/;Expires=Sun, 26 Sep 2038 21:46:38 GMT, MIAMISESSION=2fb8fda0-7e5e-4c38-b4b4-133eed1127de:3715451198;Version=1;Domain=.sciencedirect.com;Path=/;HttpOnly, sd_session_id=8cbf3b233dd18641856a52d54dd78f79f01dgxrqa;Version=1;Domain=.sciencedirect.com;Path=/, acw=8cbf3b233dd18641856a52d54dd78f79f01dgxr
# ...

# %%
dom = lxml.html.fromstring(r.text)

# %%
meta = dom.xpath('//meta')

# %%
for item in meta:
    print(item.items())
# Out:
# [('name', 'citation_pii'), ('content', 'S037702731830129X')]
# [('name', 'citation_issn'), ('content', '0377-0273')]
# [('name', 'citation_volume'), ('content', '359')]
# [('name', 'citation_lastpage'), ('content', '20')]
# [('name', 'citation_publisher'), ('content', 'Elsevier')]
# [('name', 'citation_firstpage'), ('content', '1')]
# [('name', 'citation_journal_title'), ('content', 'Journal of Volcanology and Geothermal Research')]
# [('name', 'citation_type'), ('content', 'JOUR')]
# [('name', 'citation_doi'), ('content', '10.1016/j.jvolgeores.2018.05.020')]
# [('name', 'dc.identifier'), ('content', '10.1016/j.jvolgeores.2018.05.020')]
# [('name', 'citation_article_type'), ('content', 'Full-length article')]
# [('property', 'og:description'), ('content', 'Shallow magmatic intrusions are prevalent in volcanic settings worldwide. Understanding how these intrusions interact and influence their volcanic hos…')]
# ...

# %%
meta1.items()
# Out:
# [('name', 'citation_issn'), ('content', '0377-0273')]

# %%
r.content.splitlines()
# Out:
# [b'',
#  b'      <!doctype html>',
#  b"      <html lang='en-us'>",
#  b'          <head>',
#  b'              <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">',
#  b'              <meta name="SDTech" content="Proudly brought to you by the SD Technology team in London, Dayton, and Amsterdam">',
#  b"              <meta charset='utf-8'>",
#  b'              <meta name="robots" content="NOINDEX,FOLLOW,NOARCHIVE,NOODP,NOYDIR">',
#  b'              <title>Internal Server Error</title>',
#  b'              <link rel="icon" href="https://sdfestaticassets-us-east-1.sciencedirectassets.com/shared-assets/15/images/favSD.ico" type="image/x-icon" />',
#  b"              <link rel='stylesheet' href=https://sdfestaticassets-us-east-1.sciencedirectassets.com/prod/2efdf6e3b3bfafb2a279f3a295538060ed05b2c8/style.css>",
#  b'              ',
#  b'              <script src="//cdn.optimizely.com/js/204774041.js"></script>',
# ...
